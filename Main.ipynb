# %%
import pandas as pd
import numpy as np
import ssl


ssl._create_default_https_context = ssl._create_unverified_context

pgh_tree_data = pd.read_csv("https://data.wprdc.org/datastore/dump/1515a93c-73e3-4425-9b35-1cd11b2196da",
                           index_col="id", 
                           parse_dates=True)
pgh_tree_data.head()
# Out:
# /opt/tljh/user/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                           id address_number         street  \
# neighborhood
# Homewood North     754166088           7428  MONTICELLO ST
# Oakwood           1946899269            220     BALVER AVE
# South Side Flats  1431517397           2822      SIDNEY ST
# East Allegheny     994063598            608     SUISMON ST
# Highland Park     1591838573           1135   N NEGLEY AVE
#
#                          common_name   scientific_name  height  width  \
# neighborhood
# Homewood North                 Stump             Stump     0.0    0.0
# Oakwood           Linden: Littleleaf     Tilia cordata     0.0    0.0
# South Side Flats          Maple: Red       Acer rubrum    22.0    6.0
# East Allegheny        Maple: Freeman  Acer x freemanii    25.0   10.0
# Highland Park          Maple: Norway  Acer platanoides    52.0   13.0
#
#                   growth_space_length  growth_space_width  \
# neighborhood
# Homewood North                   10.0                 2.0
# Oakwood                          99.0                99.0
# South Side Flats                  6.0                 3.0
# East Allegheny                    3.0                 3.0
# Highland Park                    99.0                99.0
#
#                      growth_space_type  ...  overall_benefits_dollar_value  \
# neighborhood                            ...
# Homewood North             Well or Pit  ...                            NaN
# Oakwood           Open or Unrestricted  ...                     125.178322
# South Side Flats           Well or Pit  ...                      77.767116
# East Allegheny             Well or Pit  ...                      81.838259
# Highland Park     Open or Unrestricted  ...                     390.538994
#
#                   council_district  ward         tract public_works_division  \
# neighborhood
# Homewood North                 9.0  13.0  4.200313e+10                   2.0
# Oakwood                        2.0  28.0  4.200356e+10                   5.0
# South Side Flats               3.0  16.0  4.200316e+10                   3.0
# East Allegheny                 1.0  23.0  4.200356e+10                   1.0
# Highland Park                  7.0  11.0  4.200311e+10                   2.0
#
#                   pli_division  police_zone  fire_zone   latitude  longitude
# neighborhood
# Homewood North            13.0          5.0       3-17  40.458169 -79.889724
# Oakwood                   28.0          6.0       1-19  40.429269 -80.067868
# South Side Flats          16.0          3.0       4-24  40.426797 -79.965035
# East Allegheny            23.0          1.0        1-6  40.455503 -79.999276
# Highland Park             11.0          5.0        3-9  40.476667 -79.924106
#
# [5 rows x 57 columns]
